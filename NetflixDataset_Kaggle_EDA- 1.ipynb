# %% [markdown]
# ## EDA ON NETFLIX DATASET USING PYTHON
# https://www.kaggle.com/code/swatikhedekar/eda-on-netflix-dataset-using-pyhton

# %% [markdown]
# ### Data Decription:
# This Netflix Dataset has information about the TV shows and Movies available on Netflix from the year 2008 to 2021. Netflix is an application that keeps growing exponentially whole around the world and it is the most famous streaming platform.
#
# **This dataset collected from Netflix of different TV shows and Movies from the year 2008 to 2021.**
# - show_id: Gives the information about show id.
# - type: Gives information about 2 different unique values one is TV Show and another is Movie.
# - title: Gives information about the title of Movie or TV Show.
# - director: Gives information about the director who directed the Movie or TV Show.
# - cast: Gives information about the cast who plays role in Movie or TV Show.
# - country: Gives information about the Name of country.
# - date_added: Gives information about the tv shows or movie released.
# - release_year: Gives information about the year when Movie or TV Show was released.
# - rating: Gives information about the Movie or TV Show are in which category (eg like the movies are only for students, or adults, etc).
# - duration: Gives information about the duration of Movie or TV Show.
# - listed_in: Gives information about the genre of Movie or TV Show.
# - description: Gives information about the description of Movie or TV Show.
#
# **This Exploratory Data Analysis is to practice Python skills learned till now on a structured data set including loading, inspecting, wrangling, exploring, and drawing conclusions from data. The notebook has observations with each step in order to explain thoroughly how to approach the data set. Based on the observation some questions also are answered in the notebook for the reference though not all of them are explored in the analysis.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
# %matplotlib inline

# %%
netflix = pd.read_csv(r"C:\Users\HP\0DS Learnbay\netflix_titles_2021.csv\netflix_titles_2021.csv")
netflix  
#or use netflix.head() and netflix.tail() for basic understanding of dataset
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.size  #total number of elements
# Out:
# 105684

# %%
netflix.columns  
#you should usually do this for every dataset. columns are easily accesssible 
#from this array for later use
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.dtypes  #another good function b4 you start any analysis
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.info()   
#VERY USEFUL FUNC, use this instead of dtypes 2 get null value count as well
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.describe()  #statistical info on numerical columns
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix.describe(include = 'all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
#finding out how many values are unique in the dataset
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# ## Data Processing (Data Cleaning)
# - **Check for missing values**
# - **Fill null values**

# %%
null_values= netflix.isnull().sum()
null_values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
null_percent= (netflix.isnull().sum()/len(netflix))*100
null_percent
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
null_data = pd.concat([null_values,null_percent], axis = 1, 
                      keys= ['Total Null Values', '% of Null Values'])
null_data
# Out:
#               Total Null Values  % of Null Values
# show_id                       0          0.000000
# type                          0          0.000000
# title                         0          0.000000
# director                   2634         29.908028
# cast                        825          9.367549
# country                     831          9.435676
# date_added                   10          0.113546
# release_year                  0          0.000000
# rating                        4          0.045418
# duration                      3          0.034064
# listed_in                     0          0.000000
# description                   0          0.000000

# %%
#From above, we see that max null values are present in te 'director', 'cast' 
#and 'country' columns. We will delete the rows with null values in 'director' 
#& 'cast' columns coz we do not need them at the moment.
netflix_copy = netflix.copy()
netflix_copy
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_copy = netflix_copy.dropna(subset= ['director', 'cast'], how = 'any')
netflix_copy
# Out:
#      show_id     type                             title  \
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# 8         s9  TV Show     The Great British Baking Show
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# ...

# %%
#filling the rest of the missing values
netflix_copy.fillna({'country':'missing', 'rating':'missing', 
                     'duration':'missing'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\3192139549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy.fillna({'country':'missing', 'rating':'missing',

# %%
netflix_copy.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## Preprocessing
# - Dealing with duplicate rows
# - Find number of duplicate rows in the dataset.
# - Print the duplicate entries and analyze.
# - Drop the duplicate entries from the dataset.

# %%
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
netflix.duplicated().sum()
#no duplicate rows are present in this dataset
# Out:
# 0

# %%
netflix_copy.shape
# Out:
# (5700, 12)

# %%
netflix_copy.to_csv('netflix_clean.csv')

# %% [markdown]
# ## EDA QUESTIONS
# ### 1) What different types of content is available on netflix?
#
# or
#
# ### 1) How many TV hows & movies are in the dataset? Show with bar graph

# %%
netflix_copy.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# ...

# %%
print((netflix_copy['type']== 'TV Show').sum())
print((netflix_copy['type']== 'Movie').sum())
# Out:
# 178
# 5522

# %%
#SINCE 'type' HAS NO NULL VALUES, WE CAN DO THIS EDA ON THE ENTIRE DATASET
print((netflix['type']== 'TV Show').sum())
print((netflix['type']== 'Movie').sum())
# Out:
# 2676
# 6131

# %%
#better methods
netflix.groupby('type')['title'].count().sort_values(ascending = False)
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: title, dtype: int64

# %%
#another method
netflix.type.value_counts().to_frame('Value_Count')
# Out:
#          Value_Count
# type
# Movie           6131
# TV Show         2676

# %%
sns.countplot(x= netflix['type'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# ### 2)Percentage of content on netflix

# %%
value_count = netflix_copy['type'].value_counts()
plt.pie(value_count, labels = ['Movie', 'TV Show'], autopct = '%.2f%%')
plt.legend(title = '% of most watched content on Netflix', loc = 'upper right')

# %%
value_count = netflix['type'].value_counts()
plt.pie(value_count, labels = ['Movie', 'TV Show'], autopct = '%.2f%%')
plt.legend(title = '% of most watched content on Netflix', loc = 'upper right')

# %% [markdown]
# ### *** These pie plots tell us that a maximum of data about TV shows is removed from the copy version.

# %% [markdown]
# ### Converting object into datetime formate of "date_added"

# %%
netflix_copy.iloc[1206:1212]
# Out:
#      show_id   type                      title          director  \
# 1905   s1906  Movie               Cold Harbour    Carey McKenzie
# 1909   s1910  Movie        Free State of Jones         Gary Ross
# 1912   s1913  Movie  Hunt for the Wilderpeople     Taika Waititi
# 1916   s1917  Movie                       Rize  David LaChapelle
# 1919   s1920  Movie          The American Game  Mostafa Abu Seif
# 1920   s1921  Movie            The Book of Sun       Faris Godus
#
#                                                    cast  \
# 1905  Tony Kgoroge, Yu Nan, Thomas Gumede, Deon Lotz...
# 1909  Matthew McConaughey, Gugu Mbatha-Raw, Mahersha...
# 1912  Sam Neill, Julian Dennison, Rima Te Wiata, Rac...
# 1916                        Tommy the Clown, Tight Eyez
# 1919  Nahed El Sebaï, Ahmed Fahmi, Shaima Saif, Bayo...
# 1920  Baraa Alem, Ismail Alhassan, Ahmed Saddam, Soh...
#
#                             country       date_added  release_year rating  \
# ...

# %%
netflix_copy['date_added']= netflix_copy['date_added'].apply(lambda x: x.strip())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\1286668217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['date_added']= netflix_copy['date_added'].apply(lambda x: x.strip())

# %%
netflix_copy['date_added'] = pd.to_datetime(netflix_copy['date_added'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\3695652092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['date_added'] = pd.to_datetime(netflix_copy['date_added'])

# %%
#pd.to_datetime?

# %%
netflix_copy['year_added'] = netflix_copy["date_added"].dt.year
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\4131667641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['year_added'] = netflix_copy["date_added"].dt.year

# %%
netflix_copy['month_added'] = netflix_copy['date_added'].dt.month
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\2322339061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['month_added'] = netflix_copy['date_added'].dt.month

# %%
netflix_copy.sample(10)
# Out:
#      show_id   type                              title  \
# 8079   s8080  Movie                      Staged Killer
# 5937   s5938  Movie                     The Short Game
# 2166   s2167  Movie  A Go! Go! Cory Carson Summer Camp
# 7380   s7381  Movie                         Mahabharat
# 6883   s6884  Movie    Goosebumps 2: Haunted Halloween
# 1823   s1824  Movie                           Panoptic
# 829     s830  Movie                   Dog Gone Trouble
# 2463   s2464  Movie                 Grandmother's Farm
# 594     s595  Movie                          Star Trek
# 256     s257  Movie           Nneka The Pretty Serpent
#
#                      director  \
# 8079          Christopher Ray
# 5937           Josh Greenbaum
# 2166  Stanley Moore, Alex Woo
# 7380               Amaan Khan
# 6883               Ari Sandel
# 1823                 Rana Eid
# 829             Kevin Johnson
# 2463               Ahmed Zein
# 594               J.J. Abrams
# 256                Tosin Igho
#
# ...

# %%
netflix_copy.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_added               int32
# month_added              int32
# dtype: object

# %% [markdown]
# ## Doing the same for the entire dataset.

# %%
netflix1 = netflix.copy()
netflix1.dropna(subset= ['date_added'], how = 'any', inplace = True)
netflix1.sample(3)
# Out:
#      show_id     type                               title        director  \
# 2779   s2780    Movie  Crip Camp: A Disability Revolution             NaN
# 8560   s8561  TV Show                       The Womanizer             NaN
# 4428   s4429    Movie               Christmas With A View  Justin G. Dyck
#
#                                                    cast        country  \
# 2779                                                NaN  United States
# 8560  Lan Cheng-lung, Sonia Sui, James Wen, Bianca B...          China
# 4428  Scott Cavalheiro, Kaitlyn Leeb, Vivica A. Fox,...         Canada
#
#              date_added  release_year rating  duration  \
# 2779     March 25, 2020          2020      R   108 min
# 8560  September 1, 2016          2010  TV-MA  1 Season
# 4428   November 1, 2018          2018  TV-PG    91 min
#
#                                               listed_in  \
# 2779                                      Documentaries
# ...

# %%
netflix1['date_added']= netflix1['date_added'].apply(lambda x: x.strip())
netflix1['date_added'] = pd.to_datetime(netflix1['date_added'])
netflix1['year_added'] = netflix1["date_added"].dt.year
netflix1['month_added'] = netflix1["date_added"].dt.month

# %%
netflix1.sample(3)
# Out:
#      show_id     type                        title      director  \
# 1521   s1522    Movie                        Rabun  Yasmin Ahmad
# 2683   s2684    Movie                     Mischief   Emcy Joseph
# 8411   s8412  TV Show  The Making of Frozen Planet           NaN
#
#                                                    cast  \
# 1521  M. Rajoli, Kartina Aziz, Rozie Rashid, Irwan I...
# 2683  Suraj Venjaramoodu, Soubin Shahir, Surabhi Lak...
# 8411                                 David Attenborough
#
#                                                 country date_added  \
# 1521                                           Malaysia 2020-12-18
# 2683                                              India 2020-04-15
# 8411  United Kingdom, United States, Spain, Germany,... 2016-01-28
#
#       release_year rating  duration  \
# 1521          2004  TV-PG    85 min
# 2683          2019  TV-PG   120 min
# 8411          2012  TV-PG  1 Season
#
# ...

# %% [markdown]
# ### 3)What is the correlation between columns?

# %%
cr= netflix_copy.corr(numeric_only = True)
print(cr)
plt.subplots(figsize = (5,5))
sns.heatmap(cr, annot = True)
#we observe that there is almost no correlation b/w these columns
# Out:
#               release_year  year_added  month_added
# release_year      1.000000    0.032265    -0.062903
# year_added        0.032265    1.000000    -0.170078
# month_added      -0.062903   -0.170078     1.000000
# <Axes: >

# %%
cr= netflix1.corr(numeric_only = True)
print(cr)
plt.subplots(figsize = (5,5))
sns.heatmap(cr, annot = True)
#we observe that there is almost no correlation b/w these columns
# Out:
#               release_year  year_added  month_added
# release_year      1.000000    0.111531    -0.039179
# year_added        0.111531    1.000000    -0.160421
# month_added      -0.039179   -0.160421     1.000000
# <Axes: >

# %% [markdown]
# ### 4.1)Distribution of Ratings? & What are the different rating defined by Netflix?

# %%
netflix_copy['rating'].unique()
# Out:
# array(['TV-MA', 'PG', 'TV-14', 'PG-13', 'TV-PG', 'TV-Y', 'R', 'TV-G',
#        'TV-Y7', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR', 'missing'], dtype=object)

# %%
len(netflix_copy['rating'].unique())
# Out:
# 18

# %%
ax = sns.countplot(x = netflix_copy['rating'])
plt.xticks(rotation = 60)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1939'),
#  Text(0, 0, '279'),
#  Text(0, 0, '1329'),
#  Text(0, 0, '477'),
#  Text(0, 0, '456'),
#  Text(0, 0, '102'),
#  Text(0, 0, '789'),
#  Text(0, 0, '96'),
#  Text(0, 0, '123'),
#  Text(0, 0, '40'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '58'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1')]

# %%
#FOR THE ENTIRE DATASET, NaN values are not considered in the plot
ax = sns.countplot(x = netflix['rating'])  
plt.xticks(rotation = 60)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '490'),
#  Text(0, 0, '3207'),
#  Text(0, 0, '287'),
#  Text(0, 0, '2160'),
#  Text(0, 0, '863'),
#  Text(0, 0, '307'),
#  Text(0, 0, '334'),
#  Text(0, 0, '799'),
#  Text(0, 0, '220'),
#  Text(0, 0, '41'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '80'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3')]

# %% [markdown]
# ### Observations:
# - There are 17 types of ratings in netflix (one more is missing, filled by me for null data)
# - Mostly preferred content rating is TV-MA, TV-14 and R, whereas NC-17, 74 min, 84 min, 66 min, UR and TV-Y7-FV are least preferred.
# - Observations remain same for both plots.

# %% [markdown]
# ### 4.2) Distribution of rating wrt type of content?

# %%
plt.subplots(figsize = (10,12))
ax = sns.countplot(x = netflix_copy['rating'], hue = netflix_copy['type'], palette = ['b','g'])
plt.xticks(rotation = 60)
for container in ax.containers:
    ax.bar_label(container)

# %%
#for entire dataset
plt.subplots(figsize = (10,12))
ax = sns.countplot(x = netflix['rating'], hue = netflix['type'], palette =['g','b'])
plt.xticks(rotation = 60)
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Adding new column for genre:
# genre_types(genre 1, genre 2, genre 3)

# %%
genre_types = netflix_copy['listed_in'].str.split("," , n= 2)
genre_types
# Out:
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 5                  [TV Dramas,  TV Horror,  TV Mysteries]
# 6                              [Children & Family Movies]
# 7       [Dramas,  Independent Movies,  International M...
# 8                         [British TV Shows,  Reality TV]
#                               ...
# 8801          [Dramas,  International Movies,  Thrillers]
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 5700, dtype: object

# %%
genre_types.str.get(0)
# Out:
# 2                 Crime TV Shows
# 5                      TV Dramas
# 6       Children & Family Movies
# 7                         Dramas
# 8               British TV Shows
#                   ...
# 8801                      Dramas
# 8802                 Cult Movies
# 8804                    Comedies
# 8805    Children & Family Movies
# 8806                      Dramas
# Name: listed_in, Length: 5700, dtype: object

# %%
netflix_copy['Genre 1'] = genre_types.str.get(0)
netflix_copy['Genre 2'] = genre_types.str.get(1)
netflix_copy['Other Genres'] = genre_types.str.get(2)
netflix_copy.sample(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\1826276551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['Genre 1'] = genre_types.str.get(0)
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\1826276551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['Genre 2'] = genre_types.str.get(1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\1826276551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
netflix_copy['Genre 1'].describe()
# Out:
# count       5700
# unique        33
# top       Dramas
# freq        1586
# Name: Genre 1, dtype: object

# %%
netflix_copy['Genre 2'].describe()
# Out:
# count                      4485
# unique                       35
# top        International Movies
# freq                       1545
# Name: Genre 2, dtype: object

# %%
netflix_copy['Other Genres'].describe()
# Out:
# count                      2434
# unique                       29
# top        International Movies
# freq                        881
# Name: Other Genres, dtype: object

# %% [markdown]
# ### drop 'listed_in' column because there's no need for it anymore

# %%
netflix_copy.drop('listed_in', axis = 1, inplace = True)
netflix_copy.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\3895331415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy.drop('listed_in', axis = 1, inplace = True)
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# ...

# %%
netflix_copy.duplicated().sum()
# Out:
# 0

# %%
netflix_copy.groupby('Genre 1')['title'].count().sort_values(ascending = False)
# Out:
# Genre 1
# Dramas                          1586
# Comedies                        1184
# Action & Adventure               848
# Children & Family Movies         548
# Documentaries                    397
# Stand-Up Comedy                  309
# Horror Movies                    274
# International Movies             122
# Classic Movies                    73
# Thrillers                         65
# International TV Shows            59
# Crime TV Shows                    37
# Movies                            30
# British TV Shows                  21
# Independent Movies                20
# Anime Features                    19
# Music & Musicals                  18
# Sci-Fi & Fantasy                  13
# Cult Movies                       12
# Kids' TV                          11
# Anime Series                      11
# Docuseries                        10
# TV Shows                           9
# Stand-Up Comedy & Talk Shows       8
# Romantic Movies                    3
# ...

# %%
netflix_copy['Genre 1'].unique()
# Out:
# array(['Crime TV Shows', 'TV Dramas', 'Children & Family Movies',
#        'Dramas', 'British TV Shows', 'Comedies', 'Thrillers',
#        'Horror Movies', 'Action & Adventure', 'International TV Shows',
#        'Documentaries', 'International Movies', 'Sci-Fi & Fantasy',
#        'Classic Movies', 'TV Shows', 'Stand-Up Comedy', 'Movies',
#        'Stand-Up Comedy & Talk Shows', 'Anime Features', 'Anime Series',
#        'Reality TV', 'Romantic TV Shows', 'Cult Movies',
#        'Independent Movies', 'Docuseries', 'Classic & Cult TV',
#        "Kids' TV", 'Music & Musicals', 'Romantic Movies', 'LGBTQ Movies',
#        'TV Action & Adventure', 'TV Comedies', 'TV Horror'], dtype=object)

# %%
netflix_copy.groupby('Genre 2')['title'].count().sort_values(ascending = False)
# Out:
# Genre 2
#  International Movies            1545
#  Dramas                           744
#  Independent Movies               572
#  Comedies                         440
#  Thrillers                        232
#  Romantic Movies                  170
#  Music & Musicals                 119
#  Sci-Fi & Fantasy                 109
#  Horror Movies                     71
#  Sports Movies                     68
#  Anime Features                    49
#  Faith & Spirituality              49
#  Cult Movies                       44
#  International TV Shows            41
#  Children & Family Movies          31
#  Classic Movies                    30
#  LGBTQ Movies                      30
#  TV Dramas                         23
#  Romantic TV Shows                 22
#  Documentaries                     21
#  TV Comedies                       20
#  Korean TV Shows                    9
#  Stand-Up Comedy                    9
#  Crime TV Shows                     8
# ...

# %%
netflix_copy.groupby('Other Genres')['title'].count().sort_values(ascending = False)
# Out:
# Other Genres
#  International Movies            881
#  Romantic Movies                 431
#  Thrillers                       278
#  Music & Musicals                191
#  Independent Movies              159
#  Sci-Fi & Fantasy                115
#  Sports Movies                    95
#  Dramas                           68
#  LGBTQ Movies                     52
#  TV Dramas                        36
#  TV Comedies                      16
#  Cult Movies                      14
#  Comedies                         12
#  Faith & Spirituality             11
#  Spanish-Language TV Shows        10
#  TV Mysteries                     10
#  TV Action & Adventure             7
#  International TV Shows            7
#  Horror Movies                     7
#  Classic Movies                    6
#  Romantic TV Shows                 5
#  TV Horror                         5
#  Children & Family Movies          4
#  Stand-Up Comedy & Talk Shows      3
#  TV Sci-Fi & Fantasy               3
# ...

# %%
netflix_gen = netflix.copy()

# %%
genre_types_full = netflix_gen['listed_in'].str.split("," , n= 2)
netflix_gen['Genre 1'] = genre_types_full.str.get(0)
netflix_gen['Genre 2'] = genre_types_full.str.get(1)
netflix_gen['Other Genres'] = genre_types_full.str.get(2)

# %%
netflix_gen['Genre 1'].describe()
# Out:
# count       8807
# unique        36
# top       Dramas
# freq        1600
# Name: Genre 1, dtype: object

# %%
netflix_gen['Genre 2'].describe()
# Out:
# count                      6787
# unique                       37
# top        International Movies
# freq                       1722
# Name: Genre 2, dtype: object

# %%
netflix_gen['Other Genres'].describe()
# Out:
# count                      3729
# unique                       33
# top        International Movies
# freq                        902
# Name: Other Genres, dtype: object

# %%
netflix_gen.groupby('Genre 1')['title'].count().sort_values(ascending = False)
# Out:
# Genre 1
# Dramas                          1600
# Comedies                        1210
# Action & Adventure               859
# Documentaries                    829
# International TV Shows           774
# Children & Family Movies         605
# Crime TV Shows                   399
# Kids' TV                         388
# Stand-Up Comedy                  334
# Horror Movies                    275
# British TV Shows                 253
# Docuseries                       221
# Anime Series                     176
# International Movies             128
# Reality TV                       120
# TV Comedies                      120
# Classic Movies                    80
# TV Dramas                         67
# Thrillers                         65
# Movies                            57
# TV Action & Adventure             40
# Stand-Up Comedy & Talk Shows      34
# Romantic TV Shows                 32
# Classic & Cult TV                 22
# Anime Features                    21
# ...

# %%
netflix_gen.groupby('Genre 2')['title'].count().sort_values(ascending = False)
# Out:
# Genre 2
#  International Movies            1722
#  Dramas                           758
#  Independent Movies               576
#  International TV Shows           476
#  Comedies                         452
#  TV Dramas                        320
#  TV Comedies                      269
#  Romantic TV Shows                239
#  Thrillers                        232
#  Romantic Movies                  171
#  Docuseries                       153
#  Music & Musicals                 148
#  Korean TV Shows                  131
#  Sci-Fi & Fantasy                 112
#  Sports Movies                    100
#  Reality TV                        95
#  TV Action & Adventure             83
#  Horror Movies                     75
#  Crime TV Shows                    71
#  Spanish-Language TV Shows         66
#  Kids' TV                          62
#  Faith & Spirituality              54
#  Anime Features                    50
#  Cult Movies                       45
# ...

# %%
netflix_gen.groupby('Other Genres')['title'].count().sort_values(ascending = False)
# Out:
# Other Genres
#  International Movies            902
#  Romantic Movies                 442
#  TV Dramas                       376
#  Thrillers                       280
#  Music & Musicals                209
#  TV Comedies                     192
#  Independent Movies              160
#  Sports Movies                   118
#  Sci-Fi & Fantasy                118
#  Spanish-Language TV Shows       106
#  International TV Shows          101
#  Romantic TV Shows                99
#  TV Mysteries                     76
#  Dramas                           69
#  TV Sci-Fi & Fantasy              62
#  LGBTQ Movies                     56
#  Teen TV Shows                    48
#  Science & Nature TV              47
#  TV Thrillers                     46
#  TV Action & Adventure            45
#  Reality TV                       40
#  TV Horror                        34
#  Docuseries                       21
#  Korean TV Shows                  20
#  Cult Movies                      14
# ...

# %% [markdown]
# ### 5)Finding best month for releasing content

# %%
#replacing month number in month_added column to month name
netflix_copy['month_added'].replace({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
                                     5: 'May', 6: 'June', 7: 'July', 8: 'Aug',
                                     9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}, inplace = True)
netflix_copy.head(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10672\3090973598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_copy['month_added'].replace({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# ...

# %%
netflix_copy.month_added.value_counts().to_frame('Value_count')
# Out:
#              Value_count
# month_added
# July                 535
# Dec                  511
# Oct                  507
# Jan                  503
# Apr                  501
# Mar                  497
# Aug                  492
# Sept                 475
# Nov                  468
# June                 457
# May                  405
# Feb                  349

# %%
plt.subplots(figsize = (10,8))
ax= sns.countplot(x= netflix_copy['month_added'])
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 60);

# %%
#replacing month number in month_added column to month name
netflix1['month_added'].replace({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
                                     5: 'May', 6: 'June', 7: 'July', 8: 'Aug',
                                     9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}, inplace = True)
netflix1.month_added.value_counts().to_frame('Value_count')
# Out:
#              Value_count
# month_added
# July                 827
# Dec                  813
# Sept                 770
# Apr                  764
# Oct                  760
# Aug                  755
# Mar                  742
# Jan                  738
# June                 728
# Nov                  705
# May                  632
# Feb                  563

# %%
plt.subplots(figsize = (10,8))
ax= sns.countplot(x= netflix1['month_added'])
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 60);

# %% [markdown]
# ### OBSERVATION:
# - We can see that most of the content is released in July and Jan.
# - We also see that other than a couple months, content release every month is close enough.
# - Least content is released in Feb followed by May.

# %%
plt.subplots(figsize = (12,8))
ax= sns.countplot(x= netflix_copy['month_added'], hue = netflix_copy['type'], palette = ['b','g'])
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation = 60);

# %%
plt.subplots(figsize = (12,8))
ax= sns.countplot(x= netflix1['month_added'], hue = netflix1['type'], palette = ['g','b'])
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation = 60);

# %% [markdown]
# ### OBSERVATIONS (based on second graph for entire dataset):
# - On plotting movies and shows together, for the months with least content released, ie Feb followed by May, we see that the number of TV Shows released for both months are close to their average value but the number of movies released during those months decrease.

# %% [markdown]
# ## 6)Highest watched genres on netflix?

# %%
netflix_gen.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# ### TOP 5 GENRES FROM EACH COLUMN TO FIND MOST POPULAR GENRES.

# %% [markdown]
# ### ** CORRECTED NOW

# %%
a = netflix_gen.groupby('Genre 1')['title'].count().sort_values(ascending = False).head(5)
a1 = pd.DataFrame([a.index, a.values])
a1= a1.rename(columns = a1.iloc[0]).loc[1:]
a1
# Out:
#   Dramas Comedies Action & Adventure Documentaries International TV Shows
# 1   1600     1210                859           829                    774

# %%
b = netflix_gen.groupby('Genre 2')['title'].count().sort_values(ascending = False).head(5)
b1 = pd.DataFrame([b.index, b.values])
b1= b1.rename(columns = b1.iloc[0]).loc[1:]
b1.rename(columns= lambda x: x.strip(), inplace = True)  ##WHITESPACE WAS THE PROBLEM
b1
# Out:
#   International Movies Dramas Independent Movies International TV Shows  \
# 1                 1722    758                576                    476
#
#   Comedies
# 1      452

# %%
c = netflix_gen.groupby('Other Genres')['title'].count().sort_values(ascending = False).head(5)
c1 = pd.DataFrame([c.index, c.values])
c1= c1.rename(columns = c1.iloc[0]).loc[1:]
c1.rename(columns= lambda x: x.strip(), inplace = True)  ##WHITESPACE WAS THE PROBLEM
c1
# Out:
#   International Movies Romantic Movies TV Dramas Thrillers Music & Musicals
# 1                  902             442       376       280              209

# %%
genre_frame= pd.concat([a1,b1,c1], axis =0)   #THIS IS WORKING
genre_frame
# Out:
#   Dramas Comedies Action & Adventure Documentaries International TV Shows  \
# 1   1600     1210                859           829                    774
# 1    758      452                NaN           NaN                    476
# 1    NaN      NaN                NaN           NaN                    NaN
#
#   International Movies Independent Movies Romantic Movies TV Dramas Thrillers  \
# 1                  NaN                NaN             NaN       NaN       NaN
# 1                 1722                576             NaN       NaN       NaN
# 1                  902                NaN             442       376       280
#
#   Music & Musicals
# 1              NaN
# 1              NaN
# 1              209

# %%
genre_frame.loc['Total count'] = genre_frame.sum()
genre_frame
# Out:
#             Dramas Comedies Action & Adventure Documentaries  \
# 1             1600     1210                859           829
# 1              758      452                NaN           NaN
# 1              NaN      NaN                NaN           NaN
# Total count   2358     1662                859           829
#
#             International TV Shows International Movies Independent Movies  \
# 1                              774                  NaN                NaN
# 1                              476                 1722                576
# 1                              NaN                  902                NaN
# Total count                   1250                 2624                576
#
#             Romantic Movies TV Dramas Thrillers Music & Musicals
# 1                       NaN       NaN       NaN              NaN
# 1                       NaN       NaN       NaN              NaN
# 1                       442       376       280              209
# ...

# %%
ax= genre_frame.iloc[3].plot(kind= 'bar')
ax.bar_label(ax.containers[0]);

# %%
genre_frame.iloc[3].plot(kind= 'pie', autopct = '%.2f%%')
plt.title('TOP GENRES ON NETFLIX')
# Out:
# Text(0.5, 1.0, 'TOP GENRES ON NETFLIX')

# %% [markdown]
# ### OBSERVATIONS:
# - We see that out of the top 5 genres from each genre column, there are TOP 11 genres(ignoring the repeated ones) evaluated for the entire dataset.
# - We also observe that 'International Movies' & 'Dramas' are the most wanted content available on Netflix.

# %% [markdown]
# ### BELOW METHOD NOT NEEDED ANYMORE.

# %%
#GOING BACK TO MY ORIGINAL METHOD
#g1 = netflix_copy.groupby('Genre 1')['title'].count().sort_values(ascending = False).head(5).to_frame('Count').T

# %%
#g2 = netflix_copy.groupby('Genre 2')['title'].count().sort_values(ascending = False).head(5).to_frame('Count').T

# %%
#g3 = netflix_copy.groupby('Other Genres')['title'].count().sort_values(ascending = False).head(5).to_frame('Count').T

# %% [markdown]
# ### 7)NO. OF MOVIES & TV SHOWS RELEASED OVER THE YEARS?

# %%
netflix1.groupby('release_year')['title'].count().sort_values(ascending = False)
# Out:
# release_year
# 2018    1146
# 2017    1032
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1959       1
# 1961       1
# 1947       1
# 1966       1
# 1925       1
# Name: title, Length: 74, dtype: int64

# %%
#another method
netflix1.release_year.value_counts().to_frame('Value_count')
# Out:
#               Value_count
# release_year
# 2018                 1146
# 2017                 1032
# 2019                 1030
# 2020                  953
# 2016                  901
# ...                   ...
# 1959                    1
# 1925                    1
# 1961                    1
# 1947                    1
# 1966                    1
#
# [74 rows x 1 columns]

# %%
plt.subplots(figsize = (25,12))
sns.countplot(x = netflix1['release_year']).set_title('Count Plot for Movies & TV Shows over the years')
sns.set(font_scale = 2.5)
plt.xticks(rotation = 90);

# %%
#no point in this
plt.subplots(figsize = (25,12))
sns.countplot(x = netflix1['release_year'], hue = netflix1['type']).set_title('Count Plot for Movies & TV Shows over the years')
sns.set(font_scale = 2.5)
plt.xticks(rotation = 90);

# %% [markdown]
# ### OBSERVATIONS:
# - WE can see that with passing years, more movies & tv shows are being released every year.
# - We also observe a sudden increase in release of movies in 2016 compared to 2015.
# - Growth in release of TV shows is prominent over the years.
# - A rapid decrease in movie release in the recent years since after 2018 is also observed.
# - Whereas in case of TV shows, other than the year 2021, the release in TV Shows is increasing significantly year by year.

# %% [markdown]
# ### 8)Movies & TV Shows released on 'NETFLIX' over the years?

# %%
netflix1.year_added.value_counts().to_frame('Count').sort_index()
# Out:
#             Count
# year_added
# 2008            2
# 2009            2
# 2010            1
# 2011           13
# 2012            3
# 2013           11
# 2014           24
# 2015           82
# 2016          429
# 2017         1188
# 2018         1649
# 2019         2016
# 2020         1879
# 2021         1498

# %%
ax= netflix1.year_added.value_counts().sort_index().plot(kind = 'bar')
ax.bar_label(ax.containers[0])
sns.set(font_scale = 1.0)
plt.title('Content added on Netflix over the years')
# Out:
# Text(0.5, 1.0, 'Content added on Netflix over the years')

# %%
ax= netflix1.groupby('type')['year_added'].value_counts().sort_index().plot(kind = 'bar')
ax.bar_label(ax.containers[0])
sns.set(font_scale = 1.0)
plt.title('Movies & TV Shows added on Netflix over the years')
# Out:
# Text(0.5, 1.0, 'Movies & TV Shows added on Netflix over the years')

# %%
netflix1.groupby('type')['year_added'].value_counts().sort_index()
# Out:
# type     year_added
# Movie    2008             1
#          2009             2
#          2010             1
#          2011            13
#          2012             3
#          2013             6
#          2014            19
#          2015            56
#          2016           253
#          2017           839
#          2018          1237
#          2019          1424
#          2020          1284
#          2021           993
# TV Show  2008             1
#          2013             5
#          2014             5
#          2015            26
#          2016           176
#          2017           349
#          2018           412
#          2019           592
#          2020           595
#          2021           505
# Name: count, dtype: int64

# %% [markdown]
# ### OBSERVATIONS:
# - We can see that maximum content is added on Netflix in the year 2019.
# - We also observe that the graph displayed for overall content is similar to the graph for Movies alone.
# - There is also almost a steady growth in number of shows added on netflix over the years.

# %% [markdown]
# ### 9)What is the show id and director for 'House of cards'?

# %%
netflix.sample(2)
# Out:
#      show_id     type           title                director  \
# 5591   s5592  TV Show    Legend Quest                     NaN
# 471     s472    Movie  Day of Destiny  Akay Mason, Abosi Ogba
#
#                                                    cast country  \
# 5591  Benny Emmanuel, Mayté Cordeiro, Andrés Couturi...  Mexico
# 471   Olumide Oworu, Denola Grey, Gbemi Akinlade, Ji...     NaN
#
#              date_added  release_year rating  duration  \
# 5591  February 24, 2017          2017  TV-Y7  1 Season
# 471       July 13, 2021          2021  TV-PG   110 min
#
#                                               listed_in  \
# 5591                                           Kids' TV
# 471   Children & Family Movies, Dramas, Internationa...
#
#                                             description
# 5591  When an evil force threatens his village, a gi...
# 471   With their family facing financial woes, two t...

# %%
netflix_copy.sample(2)
# Out:
#      show_id   type                                 title        director  \
# 7531   s7532  Movie  My Babysitter's a Vampire: The Movie  Bruce McDonald
# 1470   s1471  Movie                      Alaska Is a Drag    Shaz Bennett
#
#                                                    cast        country  \
# 7531  Matthew Knight, Vanessa Morgan, Atticus Mitche...         Canada
# 1470  Martin L. Washington Jr., Maya Washington, Mat...  United States
#
#      date_added  release_year rating duration  \
# 7531 2018-10-17          2010  TV-PG   80 min
# 1470 2020-12-31          2017  TV-MA   83 min
#
#                                             description  year_added  \
# 7531  When their parents head out for the evening, E...        2018
# 1470  Tormented by bullies, an aspiring drag star wo...        2020
#
#      month_added                   Genre 1        Genre 2 Other Genres
# 7531         Oct  Children & Family Movies       Comedies          NaN
# ...

# %%
netflix_copy[netflix_copy['title'].isin(['House of Cards'])]
#apparently we have removed this from here
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, description, year_added, month_added, Genre 1, Genre 2, Other Genres]
# Index: []

# %%
#METHOD-1
netflix[netflix['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
#METHOD-2
netflix[netflix['title'].str.contains("House of Cards")]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### OBSERVATIONS:
# - For 'House of Cards', the show_id is s1060 and no data is available about  the Director.

# %% [markdown]
# ### 10)Show all the movies that were released in year 2000.

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['release_year'] == 2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['release_year'] == 2000)].shape
# Out:
# (33, 12)

# %% [markdown]
# ### OBSERVATION:
# - There are 33 movies released in year 2000.

# %% [markdown]
# ### 11)Show only the title of all TV shows that were released by India.

# %%
netflix[(netflix['type'] == 'TV Show') & (netflix['country'] == 'India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
netflix[(netflix['type'] == 'TV Show') & (netflix['country'] == 'India')]['title'].shape
# Out:
# (79,)

# %% [markdown]
# ### OBSERVATION:
# - There are 79 TV Shows made and released by India.

# %% [markdown]
# ### 12)Show top 10 directors, who gave the highest number of TV shows & Movies to Netflix?

# %%
netflix['director'].value_counts().head(10).to_frame()
# Out:
#                         count
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16
# Suhas Kadav                16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Martin Scorsese            12
# Youssef Chahine            12
# Jay Chapman                12
# Steven Spielberg           11

# %%
netflix['director'].value_counts().head(10).plot(kind = 'bar').set_title('Top 10 directors of Movies & TV Shows on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 directors of Movies & TV Shows on Netflix')

# %%
grp = netflix.groupby('type')['director'].value_counts().to_frame()
grp
# Out:
#                                 count
# type    director
# Movie   Rajiv Chilaka              19
#         Raúl Campos, Jan Suter     18
#         Suhas Kadav                16
#         Marcus Raboy               15
#         Jay Karas                  14
# ...                               ...
# TV Show Mat King                    1
#         Masaaki Yuasa               1
#         Mark Tonderai               1
#         Mark Lewis                  1
#         Ziad Doueiri                1
#
# [4576 rows x 1 columns]

# %%
dm= netflix.groupby('type').get_group('Movie')
dm['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
dtv= netflix.groupby('type').get_group('TV Show')
dtv['director'].value_counts().head(10)
# Out:
# director
# Alastair Fothergill    3
# Rob Seidenglanz        2
# Hsu Fu-chun            2
# Iginio Straffi         2
# Shin Won-ho            2
# Ken Burns              2
# Stan Lathan            2
# Thomas Astruc          1
# Quek Shio-chuan        1
# Elías León             1
# Name: count, dtype: int64

# %%
dm['director'].value_counts().head(10).plot(kind = 'bar').set_title('Top 10 directors of Movies on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 directors of Movies on Netflix')

# %%
dtv['director'].value_counts().head(10).plot(kind = 'bar').set_title('Top 10 directors of TV Shows on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 directors of TV Shows on Netflix')

# %% [markdown]
# ### OBSERVATION:
# -  Top 10 director list and plot is shown. **Rajiv Chilaka** has released maximum no. of Movies & **Alastair Fothergill** has released maximum no. of TV Shows.

# %% [markdown]
# ### 13)In how many movies/ tv shows, 'Tom Cruise' was cast?

# %%
netflix_copy[netflix_copy['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration  \
# 341  2021-08-01          1999      R  189 min
# 1254 2021-03-01          1988      R  134 min
#
#                                             description  year_added  \
# 341   Through chance, history and divine interventio...        2021
# 1254  Motivated by money, a selfish workaholic seeki...        2021
#
#      month_added         Genre 1              Genre 2 Other Genres
# 341          Aug          Dramas   Independent Movies          NaN
# 1254         Mar  Classic Movies               Dramas          NaN

# %% [markdown]
# ### OBSERVATIONS:
# - There are two movies casting Mr.Tom Cruise -"Magnolia" & "Rain Man" .

# %% [markdown]
# ### 14)How many movies got the "TV-14" rating in Canada?

# %%
netflix[(netflix['type'] ==  'Movie') & (netflix['rating'] == 'TV-14') & (netflix['country'] == 'Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
netflix[(netflix['type'] ==  'Movie') & (netflix['rating'] == 'TV-14') & (netflix['country'] == 'Canada')].shape
# Out:
# (13, 12)

# %% [markdown]
# ### OBSERVATION:
# - There are 13 movies which got 'TV-14' rating in Canada.

# %% [markdown]
# ## Conclusions:
# - We explore the Netflix dataset and saw how to clean the data and then jump into how to visualize the data with Exploratory Data Analysis. We saw some basic and advanced level charts of seaborn and matplotlib like Heatmap,Pie-chart, Bar chart, Countplot.
# - We see highest rating Tv show or Movies in dataset
# - Which month is best for movies realising and so on.
