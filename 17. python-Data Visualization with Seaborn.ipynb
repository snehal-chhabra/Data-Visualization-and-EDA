# %% [markdown]
# # Data Visualization with Seaborn: on Titanic

# %% [markdown]
# ### Seaborn was built on matplotlib and closely integrated with pandas data structure; released in 2012; it includes a large numbr of plots dedicted towards providing better insights, aong with myriad colrs and palettes. There are various types of plots; can be 2D or 3D.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('titanic.csv', index_col = 0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic[titanic['Fare'] == 0]
# Out:
#              Survived  Pclass                              Name   Sex   Age  \
# PassengerId
# 180                 0       3               Leonard, Mr. Lionel  male  36.0
# 264                 0       1             Harrison, Mr. William  male  40.0
# 272                 1       3      Tornquist, Mr. William Henry  male  25.0
# 278                 0       2       Parkes, Mr. Francis "Frank"  male   NaN
# 303                 0       3   Johnson, Mr. William Cahoone Jr  male  19.0
# 414                 0       2    Cunningham, Mr. Alfred Fleming  male   NaN
# 467                 0       2             Campbell, Mr. William  male   NaN
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"  male   NaN
# 598                 0       3               Johnson, Mr. Alfred  male  49.0
# 634                 0       1     Parr, Mr. William Henry Marsh  male   NaN
# 675                 0       2        Watson, Mr. Ennis Hastings  male   NaN
# ...

# %% [markdown]
# ## WHAT IS CORRELATION ANALYSIS?
# - Correlation analysis in research is a statistical method used to measure the strength of the linear relationship between two variables and compute their association. Simply put, it calculates the level of change in one variable due to the change in the other.

# %%
tc= titanic.corr(numeric_only = True)  #correlation matrix
tc
#titanic.corr?
#Compute pairwise correlation of columns, excluding NA/null values.
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %% [markdown]
# WHAT DO WE INFER FROM THIS TABLE?
# -------
# 1. negative values tell us about an inversely proportional relationship here between two variables and positive values tell us about a directly  proportional relatinship.
# 2. The diagonal of the dataframe/matrix is 1 for every value because variability of category A with A is 1.
# 3. The triangular matrix above the diagonal is a mirror image of the lower triangular matrix. You can consider whichever you want.
# 4. For values that are very small, such as **-0.077221 between 'Survived' and 'Pclass'** or **-0.018443 between 'Pclass' and 'Parch'**, you can ignore those here if they don't provide much information.
# 5. The correlation between 'Survived' and 'Pclass' is **-0.338481** which is a significant value and cannot be ignored. It tells us **that higher the 'Pclass' value, lower will be the chances of survival.**
#
# [**NOTE: numerically speaking, 3>2>1 which is the consideration made by the correlation matrix. When we say higher the 'Pclass' value we mean in literal number. But factually what we know is that higher the 'Pclass' , ie higher the socio-economical status/income/services bought, higher is the survival chances. Simply put, the passengers in 1st class paid more and bought better facilities and hence will be given more priority for survival than passengers in 3rd class.**]
#
# 6. Other correlations sch as 'Age' and 'SibSp' which amounts to **-0.308247** tells us that higher the age, less will be the number of siblings/spouses. It basically gives us an idea that the younger passengers are more likely to travel with their siblings/spouses than the older ones.
# 7. Another **important thing to be noted** is that correlation can only be evaluated betweeen numerical data therefore columns 'Name', 'Sex', 'Ticket', 'Cabin' and 'Embarked' are not taken into consideration. **If we need the correlation for any of these columns such as 'Embarked', we can convert it's data values into numeric format**, eg: S-> -1, C-> 0, Q-> 1, then find the correlation.
# 8. Observe the correlation **between 'SibSp' and 'Fare'** and the correlation **between 'Parch' and 'Fare'**. We note that they are both positive, therefore indicating that **higher the number of Siblings/Spouses/Parents/Children, higher is the fare.** Also, we note that the correlation value **between 'Parch' and 'Fare' is higher than the value between 'SibSp' and 'Fare'**. There could be many reasons behind it but you can make your own assumptions or evaluate firther if you have more data to work with.

# %% [markdown]
# #### THEREFORE AFTER A CORRELATION TABLE WHAT WE CAN DO IS:
# - Make a list of assumptions. Solve them and make a list of observations then give the conclusions for all together in one go.
#
# or go through them by one.
#
# - Assumption:
# - Observation: solve it through EDA
# - Conclusion:

# %% [markdown]
# ## Creating a heatmap after creating a correlation matrix
# **HEATMAP IS A MAJOR TOOL USED IN BIVARIATE ANALYSIS**
# - Syntax for heatmap: seaborn.heatmap(data, annot)
#
#        --> data: dataset with correlation parameter, or pivot table has to                  be passed
#        --> annot(default = False): If True, it displays the correlation                                        values between columns.
# - This plot heps you to analyze continuous columns of the entire dataset. It will provide relationship between two columns.

# %%
sns.heatmap(tc, annot = True, cmap = 'coolwarm', linewidth = 0.5)
# Out:
# <Axes: >

# %%
#sns.heatmap?

# %% [markdown]
# ## Histplot/Distplot/Displot using seaborn
# - Syntax: seaborn.histplot(data, bins, kde)
#
#          --> bins: Helps to get an idea of the trend of the column. Lesser the bins, less is the information and vice-versa.
#          --> kde(Kernel Density Estimation): to estimate the probability  density function of random variable.
#
# - This plot helps you to analyze single column of continuous data only. It will provide you the frequency of the data values.

# %%
sns.distplot(titanic['Age'], bins = 8, kde = False)
#UPDATED FUNCTION IS sns.histplot
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5576\358716755.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'], bins = 8, kde = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(titanic['Age'], bins = 8, kde = True)
#distplot gives density on y axis
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5576\3972810148.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'], bins = 8, kde = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(titanic['Age'], bins = 8, kde = False)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(titanic['Age'], bins = 8, kde = True)
#count on y axis
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(titanic['Age'], bins = 8, kde = False)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot?
sns.histplot?
sns.distplot?

# %%
sns.histplot(titanic['Age'], bins = 8, kde = True)
#count on y axis
#IN CASE YOU NEED THE DENSITY ON THE Y AXIS< USE kdeplot()
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# kde --> to estimate the probability density function of a random variable.
#
# **Random Variable Probability** is a mathematical concept that assigns numerical values to outcomes of a sample space. They can describe the outcomes of objective randomness (like tossing a coin) or subjective randomness(results of a cricket game).
#
# There are two types of Random Variables- Discrete and Continuous.
#
# A random variable is considered a discrete random variable when it takes specific, or distinct values within an interval. Conversely, if it takes a continuous range of values, then it is classified as a continuous random variable.
#
# https://www.geeksforgeeks.org/random-variable/

# %%
sns.distplot(titanic['Age'], bins = 8, kde = False, vertical = True)
#vertical argument plots data on y axis <-- only present in distplot
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5576\704322023.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'], bins = 8, kde = False, vertical = True)
# <Axes: ylabel='Age'>

# %% [markdown]
# ## Countplot using seaborn
# - Syntax: seaborn.countplot(data, dodge, hue)
#
#          --> dodge(default = True): the splits occuring with respect to hue, are stacked over each other.
#          --> hue: It means to compare the count of single column wrt other categorical column.
# - This plot helps you to analyze **single column of categorical data**. It will provide you the frequency of the data values.

# %%
sns.countplot?

# %%
#sns.countplot(x= 'Pclass', data = titanic, palette = ['r', 'b', 'g'])
sns.countplot(x= titanic['Pclass'], palette = ['r', 'b', 'g'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data = titanic, x= 'Pclass', hue = 'Embarked', 
              dodge = True, palette = ['b', 'g', 'r'], saturation = 0.3)
#when dodge = True
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x= titanic['Pclass'], hue = titanic['Embarked'],
              dodge = False, palette = ['b', 'g', 'r'])
#when dodge = False
#when dodge is false, the plots overlap, hence it is possible to miss one 
#of the plots or catgories like here in Pclass 3, we cannot see passengers
#from C because first S is plotted, then C, then Q. since in Pclass 3
#C is less than Q it is overlapped and hence hidden.
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ## Jointplot using seaborn:
# - Syntax: sns.jointplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze **two columns of continuous data**. It will provide you the insights or patterns between them.
# - jointplot shows the comparison between two columns along with their distribution plot.

# %%
sns.jointplot?

# %%
sns.jointplot(x= titanic['Age'], y= titanic['Fare'])
#combination of distplot(this is constant) and scatter plot(this you can 
#choose: depends on kind argument. default is scatter plot)

# %%
sns.jointplot(x= titanic['Age'], y= titanic['Fare'], kind ='hist')

# %%
sns.jointplot(x= titanic['Age'], y= titanic['Fare'], hue = titanic['Sex'])

# %% [markdown]
# ## Barplot using seaborn:
# - Syntax: sns.barplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze two columns, categorical vs continuous data. We can also plot a single column. It will provide you the insights or patterns between them.

# %%
sns.barplot?

# %%
sns.barplot(data = titanic, x= 'Embarked', y= 'Fare')
#this plot shows the average fair paid by passengers for each port
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
sns.barplot(data = titanic, x= 'Embarked', y= 'Fare', hue= 'Pclass')
#black lines are showing uncertainty in the variable data of the barplot 
#which might be there because of missing data, maybe getting effected from
#other columns
#THESE BLACK LINES ARE NOT PRESENT IN matplotlib PLOTS
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# ## Boxplot using seaborn:
# - Syntax: sns.boxplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze two columns, categorical vs continuous data. We can also plot a single column, that helps us to identify outliers.
# - It will provide you the insights or patterns between them.

# %%
sns.boxplot?

# %%
sns.boxplot(data = titanic, y= 'Age', x= 'Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data = titanic, y= 'Age', x= 'Pclass', hue= 'Embarked')
#Draw a box plot to show distributions with respect to categories.

#A box plot (or box-and-whisker plot) shows the distribution of quantitative
#data in a way that facilitates comparisons between variables or across
#levels of a categorical variable. The box shows the quartiles of the
#dataset while the whiskers extend to show the rest of the distribution,
#except for points that are determined to be "outliers" using a method
#that is a function of the inter-quartile range. The box shows the IQR
#INTER-QUARTILE RANGE.
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ## Violinplot using seaborn:
# - Syntax: sns.violinplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze two columns, categorical vs continuous data. We can also plot a single column.
# - It draws a combination of boxplot and kde.
# - It will provide you the insights or patterns between them.
#
# Draw a combination of boxplot and kernel density estimate.
#
# A violin plot plays a similar role as a box and whisker plot. It shows the
# distribution of quantitative data across several levels of one (or more)
# categorical variables such that those distributions can be compared. Unlike
# a box plot, in which all of the plot components correspond to actual
# datapoints, the violin plot features a kernel density estimation of the
# underlying distribution.
#
# This can be an effective and attractive way to show multiple distributions
# of data at once, but keep in mind that the estimation procedure is
# influenced by the sample size, and violins for relatively small samples
# might look misleadingly smooth.

# %%
sns.violinplot?

# %%
sns.violinplot(data = titanic, y= 'Age', x= 'Survived', hue= 'Sex')
#default of inner argument is box
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.violinplot(data = titanic, y= 'Age', x= 'Survived', inner ='quart', 
               hue= 'Sex', width = 0.5)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# ## Stripplot using seaborn:
# - Syntax: sns.stripplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze two columns, categorical vs continuous data. We can also plot a single column.
# - It draws a scatterplot.
# - It will provide you the insights or patterns between them.
#
# Draw a categorical scatterplot using jitter to reduce overplotting.
#
# A strip plot can be drawn on its own, but it is also a good complement
# to a box or violin plot in cases where you want to show all observations
# along with some representation of the underlying distribution.

# %%
sns.stripplot?

# %%
sns.stripplot(data= titanic, x= 'Survived', y= 'Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.stripplot(data= titanic, x= 'Survived', y= 'Age', hue= 'Sex', 
              jitter = True, palette = ['r','b'], dodge = False)
plt.title('Strip Plot')
# Out:
# Text(0.5, 1.0, 'Strip Plot')

# %%
sns.stripplot(data= titanic, x= 'Survived', y= 'Age', hue= 'Sex', 
              jitter = False, palette = ['r','b'], dodge = False)
plt.title('Strip Plot')
# Out:
# Text(0.5, 1.0, 'Strip Plot')

# %%
sns.stripplot(data= titanic, x= 'Survived', y= 'Age', hue= 'Sex', 
              jitter = True, palette = ['r','b'], dodge = True)
plt.title('Strip Plot')
# Out:
# Text(0.5, 1.0, 'Strip Plot')

# %%
sns.stripplot(data= titanic, x= 'Survived', y= 'Age', hue= 'Sex', 
              jitter = False, palette = ['r','b'], dodge = True)
plt.title('Strip Plot')
# Out:
# Text(0.5, 1.0, 'Strip Plot')

# %% [markdown]
# ## Swarmplot using seaborn:
# - Syntax: sns.swarmplot(x,y)
#
#         --> x: x-axis columns
#         --> y: y-axis columns
# - This plot helps you to analyze two columns, categorical vs continuous data. We can also plot a single column.
# - It draws a scatterplot.
# - It will provide you the insights or patterns between them.
#
# Draw a categorical scatterplot with points adjusted to be non-overlapping.
#
# This function is similar to :func: stripplot, but the points are adjusted
# (only along the categorical axis) so that they don't overlap. This gives a
# better representation of the distribution of values, but it does not scale
# well to large numbers of observations. This style of plot is sometimes
# called a "beeswarm".
#
# A swarm plot can be drawn on its own, but it is also a good complement
# to a box or violin plot in cases where you want to show all observations
# along with some representation of the underlying distribution.

# %%
sns.swarmplot?

# %%
sns.swarmplot(data = titanic, x= 'Survived', y= 'Age', hue = 'Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data = titanic, x= 'Survived', y= 'Age', hue = 'Sex', size = 3)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# ## Pairplot using seaborn:
# - Syntax: sns.pairplot(data)
#
# Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric
# variable in ``data`` will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated
# differently: a univariate distribution plot is drawn to show the marginal
# distribution of the data in each column.
#
# It is also possible to show a subset of variables or plot different
# variables on the rows and columns.
#
# This is a high-level interface for :class:`PairGrid` that is intended to
# make it easy to draw a few common styles. You should use :class:`PairGrid`
# directly if you need more flexibility.

# %%
sns.pairplot?

# %%
sns.pairplot(titanic)
#this is like the correlation matrix for two columns at a time
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data= titanic, hue= 'Sex')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data= titanic, hue= 'Sex', kind = 'reg')
#kind is by default scatter
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot?
#Plot data and a linear regression model fit.
#There are a number of mutually exclusive options for estimating the
#regression model
